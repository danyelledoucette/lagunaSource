# %%
  pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\douce\anaconda3\lib\site-packages (2.40.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\douce\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\douce\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\douce\anaconda3\lib\site-packages (from google-api-python-client) (2.7.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\douce\anaconda3\lib\site-packages (from google-api-python-client) (0.20.4)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in c:\users\douce\anaconda3\lib\site-packages (from google-api-python-client) (1.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\douce\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: six in c:\users\douce\anaconda3\lib\site-packages (from google-auth-httplib2) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\douce\anaconda3\lib\site-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\douce\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.55.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\douce\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.15.8)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\douce\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.20.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\douce\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\douce\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\douce\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\douce\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (50.3.1.post20201107)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\douce\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (2.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\douce\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\douce\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\douce\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\douce\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\douce\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\douce\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
SAMPLE_RANGE_NAME = 'Class Data!A2:E'


def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'source_secret.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        service = build('sheets', 'v4', credentials=creds)

        # Call the Sheets API
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=SAMPLE_RANGE_NAME).execute()
        values = result.get('values', [])

        if not values:
            print('No data found.')
            return

        print('Name, Major:')
        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
            print('%s, %s' % (row[0], row[4]))
    except HttpError as err:
        print(err)


if __name__ == '__main__':
    main()
# Out:
# Name, Major:
# Alexandra, English
# Andrew, Math
# Anna, English
# Becky, Art
# Benjamin, English
# Carl, Art
# Carrie, English
# Dorothy, Math
# Dylan, Math
# Edward, English
# Ellen, Physics
# Fiona, Art
# John, Physics
# Jonathan, Math
# Joseph, English
# Josephine, Math
# Karen, English
# Kevin, Physics
# Lisa, Art
# Mary, Physics
# Maureen, Physics
# Nick, Art
# Olivia, Physics
# Pamela, Math
# Patrick, Art
# Robert, English
# Sean, Physics
# Stacy, Math
# Thomas, Art
# Will, Math
